# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns

# %%
Customer_Address = pd.read_csv("C:/Users/matages/Desktop/Customer Segmentation/row_data/Customer_Address.csv")

# %%
Customer_Address.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0                  10         NaN         NaN         NaN         NaN  ...
# 1                  10         NaN         NaN         NaN         NaN  ...
# 2                   9         NaN         NaN         NaN         NaN  ...
# 3                   4         NaN         NaN         NaN         NaN  ...
# 4                   9         NaN         NaN         NaN         NaN  ...
#
# ...

# %%
Customer_Address = Customer_Address.iloc[:,0:6]

# %%
Customer_Address.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
Customer_Address.isnull().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
Customer_Address[Customer_Address.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, address, postcode, state, country, property_valuation]
# Index: []

# %%
Customer_Address["customer_id"].duplicated().sum()
# Out:
# 0

# %%
pd.set_option("display.max_rows", None)
Customer_Address["address"].value_counts()
# Out:
# address
# 3 Mariners Cove Terrace          2
# 3 Talisman Place                 2
# 64 Macpherson Junction           2
# 359 Briar Crest Road             1
# 4543 Service Terrace             1
# 0 Knutson Crossing               1
# 28156 School Park                1
# 920 Manley Crossing              1
# 38 Armistice Lane                1
# 6988 Waxwing Hill                1
# 84 Southridge Lane               1
# 8 Eagle Crest Circle             1
# 571 Golf Alley                   1
# 52408 Autumn Leaf Road           1
# 4 Loomis Hill                    1
# 1411 Jenifer Center              1
# 060 Morning Avenue               1
# 648 Rigney Pass                  1
# 336 Fordem Trail                 1
# 59 Hoepker Lane                  1
# 2864 Corscot Parkway             1
# 4658 Tennessee Street            1
# 53485 Sycamore Junction          1
# 446 Warrior Pass                 1
# 25567 Linden Court               1
# 111 Hooker Avenue                1
# ...

# %%
sns.boxplot(y = Customer_Address["postcode"],data = Customer_Address)
# Out:
# <Axes: ylabel='postcode'>

# %%
Customer_Address['state'].value_counts()
# Out:
# state
# NSW                2054
# VIC                 939
# QLD                 838
# New South Wales      86
# Victoria             82
# Name: count, dtype: int64

# %%
Customer_Address['country'].value_counts()
# Out:
# country
# Australia    3999
# Name: count, dtype: int64

# %%
sns.boxplot(x = Customer_Address['property_valuation'],data = Customer_Address)
# Out:
# <Axes: xlabel='property_valuation'>

# %%
Customer_Address.to_csv("C:/Users/matages/Desktop/Customer Segmentation/Clean_data/Customer_Address_clean.csv")
