# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns

# %%
Transaction = pd.read_csv("C:/Users/matages/Desktop/Customer Segmentation/row_data/Transaction.csv")

# %%
Transaction.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date online_order  \
# 0               1           2         2950       2017-02-25        False
# 1               2           3         3120       2017-05-21         True
# 2               3          37          402       2017-10-16        False
# 3               4          88         3135       2017-08-31        False
# 4               5          78          787       2017-10-01         True
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved           Solex     Standard        medium       medium  ...
# 1     Approved   Trek Bicycles     Standard        medium        large  ...
# 2     Approved      OHM Cycles     Standard           low       medium  ...
# 3     Approved  Norco Bicycles     Standard        medium       medium  ...
# 4     Approved  Giant Bicycles     Standard        medium        large  ...
#
# ...

# %%
Transaction[Transaction.duplicated()]
# Out:
# Empty DataFrame
# ...

# %%
Transaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Columns: 256 entries, transaction_id to Unnamed: 255
# dtypes: float64(245), int64(3), object(8)
# memory usage: 39.1+ MB

# %%
list(Transaction.columns)
# Out:
# ['transaction_id',
#  'product_id',
#  'customer_id',
#  'transaction_date',
#  'online_order',
#  'order_status',
#  'brand',
#  'product_line',
#  'product_class',
#  'product_size',
#  'list_price',
#  'standard_cost',
#  'product_first_sold_date',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26',
#  'Unnamed: 27',
#  'Unnamed: 28',
#  'Unnamed: 29',
#  'Unnamed: 30',
#  'Unnamed: 31',
#  'Unnamed: 32',
#  'Unnamed: 33',
#  'Unnamed: 34',
#  'Unnamed: 35',
#  'Unnamed: 36',
#  'Unnamed: 37',
#  'Unnamed: 38',
#  'Unnamed: 39',
#  'Unnamed: 40',
#  'Unnamed: 41',
#  'Unnamed: 42',
#  'Unnamed: 43',
#  'Unnamed: 44',
#  'Unnamed: 45',
#  'Unnamed: 46',
#  'Unnamed: 47',
#  'Unnamed: 48',
#  'Unnamed: 49',
#  'Unnamed: 50',
#  'Unnamed: 51',
#  'Unnamed: 52',
#  'Unnamed: 53',
# ...

# %%
Transaction.iloc[:,13:20]
# Out:
#        Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17  \
# 0              NaN          NaN          NaN          NaN          NaN
# 1              NaN          NaN          NaN          NaN          NaN
# 2              NaN          NaN          NaN          NaN          NaN
# 3              NaN          NaN          NaN          NaN          NaN
# 4              NaN          NaN          NaN          NaN          NaN
# ...            ...          ...          ...          ...          ...
# 19995          NaN          NaN          NaN          NaN          NaN
# 19996          NaN          NaN          NaN          NaN          NaN
# 19997          NaN          NaN          NaN          NaN          NaN
# 19998          NaN          NaN          NaN          NaN          NaN
# 19999          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 18  Unnamed: 19
# 0              NaN          NaN
# 1              NaN          NaN
# ...

# %%
Transaction.iloc[:,0:13]
# Out:
#        transaction_id  product_id  customer_id transaction_date online_order  \
# 0                   1           2         2950       2017-02-25        False
# 1                   2           3         3120       2017-05-21         True
# 2                   3          37          402       2017-10-16        False
# 3                   4          88         3135       2017-08-31        False
# 4                   5          78          787       2017-10-01         True
# ...               ...         ...          ...              ...          ...
# 19995           19996          51         1018       2017-06-24         True
# 19996           19997          41          127       2017-11-09         True
# 19997           19998          87         2284       2017-04-14         True
# 19998           19999           6         2764       2017-07-03        False
# 19999           20000          11         1144       2017-09-22         True
#
# ...

# %%
Transaction = Transaction.iloc[:,0:13]

# %%
Transaction.head(5)
# Out:
#    transaction_id  product_id  customer_id transaction_date online_order  \
# 0               1           2         2950       2017-02-25        False
# 1               2           3         3120       2017-05-21         True
# 2               3          37          402       2017-10-16        False
# 3               4          88         3135       2017-08-31        False
# 4               5          78          787       2017-10-01         True
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price standard_cost  product_first_sold_date
# ...

# %%
Transaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  object
#  4   online_order             19640 non-null  object
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  object
#  12  product_first_sold_date  19803 non-null  float64
# dtypes: float64(2), int64(3), object(8)
# ...

# %%
Transaction.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
Transaction[Transaction["brand"].isnull()]
# Out:
#        transaction_id  product_id  customer_id transaction_date online_order  \
# 136               137           0          431       2017-09-23        False
# 159               160           0         3300       2017-08-27        False
# 366               367           0         1614       2017-03-10        False
# 406               407           0         2559       2017-06-14         True
# 676               677           0         2609       2017-07-02        False
# ...               ...         ...          ...              ...          ...
# 19340           19341           0          443       2017-12-26         True
# 19383           19384           0         2407       2017-06-11        False
# 19793           19794           0         2860       2017-01-13        False
# 19859           19860           0         2468       2017-06-24         True
# 19871           19872           0           61       2017-03-17         True
#
# ...

# %% [markdown]
# brand                      197,
# product_line               197,
# product_class              197,
# product_size               197,
# standard_cost              197,
# product_first_sold_date    197
#
# all 6 columns in same null row

# %%
Transaction = Transaction.dropna(subset = ['brand'])

# %%
Transaction.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               358
# order_status                 0
# brand                        0
# product_line                 0
# product_class                0
# product_size                 0
# list_price                   0
# standard_cost                0
# product_first_sold_date      0
# dtype: int64

# %% [markdown]
# keep 358 missing in online_order

# %% [markdown]
# ### transaction_id, product_id, customer_id

# %%
len(set(Transaction['transaction_id'])) != len(Transaction['transaction_id'])
# Out:
# False

# %%
plt.subplot(1, 3, 1)
plt.boxplot(Transaction['transaction_id'])
plt.subplot(1, 3, 2)
plt.boxplot(Transaction['product_id'])
plt.subplot(3, 3, 3)
plt.boxplot(Transaction['customer_id'])
plt.show()

# %% [markdown]
# ### transaction_date

# %%
set(Transaction['transaction_date'])
# Out:
# {'2017-01-01',
#  '2017-01-02',
#  '2017-01-03',
#  '2017-01-04',
#  '2017-01-05',
#  '2017-01-06',
#  '2017-01-07',
#  '2017-01-08',
#  '2017-01-09',
#  '2017-01-10',
#  '2017-01-11',
#  '2017-01-12',
#  '2017-01-13',
#  '2017-01-14',
#  '2017-01-15',
#  '2017-01-16',
#  '2017-01-17',
#  '2017-01-18',
#  '2017-01-19',
#  '2017-01-20',
#  '2017-01-21',
#  '2017-01-22',
#  '2017-01-23',
#  '2017-01-24',
#  '2017-01-25',
#  '2017-01-26',
#  '2017-01-27',
#  '2017-01-28',
#  '2017-01-29',
#  '2017-01-30',
#  '2017-01-31',
#  '2017-02-01',
#  '2017-02-02',
#  '2017-02-03',
#  '2017-02-04',
#  '2017-02-05',
#  '2017-02-06',
#  '2017-02-07',
#  '2017-02-08',
#  '2017-02-09',
#  '2017-02-10',
#  '2017-02-11',
#  '2017-02-12',
#  '2017-02-13',
#  '2017-02-14',
#  '2017-02-15',
#  '2017-02-16',
#  '2017-02-17',
#  '2017-02-18',
#  '2017-02-19',
#  '2017-02-20',
#  '2017-02-21',
#  '2017-02-22',
#  '2017-02-23',
#  '2017-02-24',
#  '2017-02-25',
#  '2017-02-26',
#  '2017-02-27',
# ...

# %%
Transaction['transaction_date'] = pd.to_datetime(Transaction['transaction_date'], format='%Y-%m-%d')

# %%
sns.boxplot(x =Transaction['transaction_date'].dt.month, y = Transaction['transaction_date'].dt.day, data=Transaction)
plt.show()

# %%
Transaction['transaction_date'].dt.month.value_counts().plot.barh()
# Out:
# <Axes: ylabel='transaction_date'>

# %% [markdown]
# ### online_order, order_status,brand, product_line ,product_class , product_size

# %%
for i in ["online_order", "order_status", "brand", "product_line" ,"product_class" , "product_size"]:
    print(Transaction[i].value_counts())
    print("-------------------------------------------------")
# Out:
# online_order
# True     9739
# False    9706
# Name: count, dtype: int64
# -------------------------------------------------
# order_status
# Approved     19625
# Cancelled      178
# Name: count, dtype: int64
# -------------------------------------------------
# brand
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: count, dtype: int64
# -------------------------------------------------
# product_line
# Standard    14176
# Road         3970
# Touring      1234
# Mountain      423
# Name: count, dtype: int64
# -------------------------------------------------
# product_class
# medium    13826
# high       3013
# low        2964
# Name: count, dtype: int64
# -------------------------------------------------
# product_size
# medium    12990
# large      3976
# small      2837
# Name: count, dtype: int64
# -------------------------------------------------

# %% [markdown]
# ### list_price,standard_cost,product_first_sold_date

# %%
sns.boxplot(y = Transaction['list_price'], data=Transaction)
plt.show()

# %%
Transaction['standard_cost']
# Out:
# 0           $53.62
# 1          $388.92
# 2          $248.82
# 3          $381.10
# 4          $709.48
#            ...
# 19995    $1,203.40
# 19996      $312.74
# 19997       $44.71
# 19998      $136.73
# 19999    $1,580.47
# Name: standard_cost, Length: 19803, dtype: object

# %%
for i in Transaction['standard_cost']:
    if isinstance(i, str):
        Transaction['standard_cost'][Transaction['standard_cost']==i]  = (float(i.replace("$","").replace(",","")))
# Out:
# C:\Users\matages\AppData\Local\Temp\ipykernel_5000\3067667813.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Transaction['standard_cost'][Transaction['standard_cost']==i]  = (float(i.replace("$","").replace(",","")))
# C:\Users\matages\AppData\Local\Temp\ipykernel_5000\3067667813.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Transaction['standard_cost'][Transaction['standard_cost']==i]  = (float(i.replace("$","").replace(",","")))
# C:\Users\matages\AppData\Local\Temp\ipykernel_5000\3067667813.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
Transaction['standard_cost']
# Out:
# 0          53.62
# 1         388.92
# 2         248.82
# 3          381.1
# 4         709.48
#           ...
# 19995     1203.4
# 19996     312.74
# 19997      44.71
# 19998     136.73
# 19999    1580.47
# Name: standard_cost, Length: 19803, dtype: object

# %%
sns.boxplot(y = Transaction['standard_cost'], data=Transaction)
plt.show()

# %%
sns.boxplot(y = Transaction['product_first_sold_date'], data=Transaction)
plt.show()

# %%
Transaction.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date online_order  \
# 0               1           2         2950       2017-02-25        False
# 1               2           3         3120       2017-05-21         True
# 2               3          37          402       2017-10-16        False
# 3               4          88         3135       2017-08-31        False
# 4               5          78          787       2017-10-01         True
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price standard_cost  product_first_sold_date
# ...

# %%
print(Transaction["transaction_date"].min())
print(Transaction["transaction_date"].max())
# Out:
# 2017-01-01 00:00:00
# 2017-12-30 00:00:00

# %%
print("Value_counts")
for i in ["online_order", "order_status", "brand", "product_line" ,"product_class" , "product_size"]:
    print("----------------------------")
    print(Transaction[i].value_counts())
# Out:
# Value_counts
# ----------------------------
# online_order
# True     9739
# False    9706
# Name: count, dtype: int64
# ----------------------------
# order_status
# Approved     19625
# Cancelled      178
# Name: count, dtype: int64
# ----------------------------
# brand
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: count, dtype: int64
# ----------------------------
# product_line
# Standard    14176
# Road         3970
# Touring      1234
# Mountain      423
# Name: count, dtype: int64
# ----------------------------
# product_class
# medium    13826
# high       3013
# low        2964
# Name: count, dtype: int64
# ----------------------------
# product_size
# medium    12990
# large      3976
# small      2837
# Name: count, dtype: int64

# %%
Transaction[Transaction["order_status"]=="Cancelled"]
# Out:
#        transaction_id  product_id  customer_id transaction_date online_order  \
# 42                 43          76          488       2017-03-17        False
# 138               139          32         2073       2017-03-25        False
# 249               250          48         1454       2017-11-25        False
# 254               255          67         2801       2017-04-01         True
# 583               584          43         1019       2017-09-13         True
# ...               ...         ...          ...              ...          ...
# 19405           19406          79         1860       2017-05-29        False
# 19409           19410          79         1771       2017-01-15        False
# 19822           19823           3         2312       2017-12-02        False
# 19957           19958          56         2013       2017-06-04         True
# 19989           19990          55          135       2017-01-27         True
#
# ...

# %%
from scipy.stats import chi2_contingency

# %%
for i in ["online_order", "brand", "product_line" ,"product_class" , "product_size"]:
    print("------------------------------")
    print(i)
    print(chi2_contingency(pd.crosstab(Transaction[i], Transaction['order_status']))[1])
# Out:
# ------------------------------
# online_order
# 0.1127370059986726
# ------------------------------
# brand
# 0.9885064752964274
# ------------------------------
# product_line
# 0.8677531990306824
# ------------------------------
# product_class
# 0.0754477285776431
# ------------------------------
# product_size
# 0.895756916868361

# %%
pd.crosstab(Transaction["product_class"], Transaction['order_status'])
# Out:
# order_status   Approved  Cancelled
# product_class
# high               2978         35
# low                2946         18
# medium            13701        125

# %%
(Transaction.groupby('product_class')['order_status'].value_counts(normalize=True)
   .unstack('order_status').plot.bar(stacked=True))
# Out:
# <Axes: xlabel='product_class'>

# %%
Transaction["Profit"] = Transaction["list_price"] - Transaction["standard_cost"]
Transaction[["product_id","Profit","list_price","standard_cost","brand"]].drop_duplicates(keep='first').sort_values("product_id",ascending=True)
# Out:
#        product_id     Profit  list_price standard_cost           brand
# 17468           0  75.139976      742.54    667.400024      OHM Cycles
# 34              0     167.21      544.05        376.84  Norco Bicycles
# 63              0     110.81      499.53        388.72   Trek Bicycles
# 82              0     110.56      235.63        125.07      OHM Cycles
# 99              0     179.44      478.16        298.72           Solex
# ...           ...        ...         ...           ...             ...
# 123            98     693.76      795.34        101.58      OHM Cycles
# 33             99     189.28     1720.70       1531.42   Trek Bicycles
# 523            99     456.45     1227.34        770.89      OHM Cycles
# 170           100     830.24     1036.59        206.35  Norco Bicycles
# 889           100     152.55     1386.84       1234.29   Trek Bicycles
#
# [203 rows x 5 columns]

# %%
Transaction[["product_id","Profit"]]
# Out:
#        product_id   Profit
# 0               2    17.87
# 1               3  1702.55
# 2              37  1544.61
# 3              88   817.36
# 4              78  1055.82
# ...           ...      ...
# 19995          51   802.26
# 19996          41   104.24
# 19997          87  1592.19
# 19998           6    91.15
# 19999          11   195.34
#
# [19803 rows x 2 columns]

# %%
Transaction[Transaction["Profit"] <10]
# Out:
#        transaction_id  product_id  customer_id transaction_date online_order  \
# 60                 61           0         1839       2017-02-24        False
# 88                 89           0         2682       2017-04-04         True
# 195               196          19         1315       2017-12-21         True
# 722               723          19         1284       2017-07-28        False
# 810               811          19          700       2017-07-10         True
# ...               ...         ...          ...              ...          ...
# 19291           19292          19          150       2017-10-16        False
# 19485           19486          19         3110       2017-10-16         True
# 19599           19600          19         1137       2017-07-09        False
# 19933           19934          19         1752       2017-10-22        False
# 19959           19960          19          816       2017-11-06         True
#
# ...

# %%
Transaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19803 entries, 0 to 19999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           19803 non-null  int64
#  1   product_id               19803 non-null  int64
#  2   customer_id              19803 non-null  int64
#  3   transaction_date         19803 non-null  datetime64[ns]
#  4   online_order             19445 non-null  object
#  5   order_status             19803 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               19803 non-null  float64
#  11  standard_cost            19803 non-null  object
#  12  product_first_sold_date  19803 non-null  float64
#  13  Profit                   19803 non-null  object
# ...

# %%
Transaction['transaction_date'].dt.month.value_counts().plot.barh()
# Out:
# <Axes: ylabel='transaction_date'>

# %%
Transaction.to_csv("C:/Users/matages/Desktop/Customer Segmentation/Clean_data/Transaction_Clean.csv")
