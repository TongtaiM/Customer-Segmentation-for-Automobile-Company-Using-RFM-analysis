# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns

# %%
New_Customer = pd.read_csv("C:/Users/matages/Desktop/Customer Segmentation/row_data/New_Customer.csv")

# %%
New_Customer.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#           DOB                   job_title job_industry_category  \
# 0  1957-07-12             General Manager         Manufacturing
# 1  1970-03-22         Structural Engineer              Property
# 2  1974-08-28      Senior Cost Accountant    Financial Services
# 3  1979-01-28  Account Representative III         Manufacturing
# 4  1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  Unnamed: 246  \
# 0      Mass Customer                  N      Yes  ...           NaN
# ...

# %%
New_Customer = New_Customer.iloc[:,0:23]

# %%
New_Customer[New_Customer.duplicated()]
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, gender, past_3_years_bike_related_purchases, DOB, job_title, job_industry_category, wealth_segment, deceased_indicator, owns_car, tenure, address, postcode, state, country, property_valuation, Unnamed: 16, Unnamed: 17, Unnamed: 18, Unnamed: 19, Unnamed: 20, Rank, Value]
# Index: []
#
# [0 rows x 23 columns]

# %%
New_Customer.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Unnamed: 16                              0
# Unnamed: 17                              0
# Unnamed: 18                              0
# Unnamed: 19                              0
# Unnamed: 20                              0
# Rank                                     0
# ...

# %% [markdown]
# ### first_name	last_name

# %%
New_Customer[New_Customer["last_name"].isnull()]
# Out:
#      first_name last_name  gender  past_3_years_bike_related_purchases  \
# 12         Olag       NaN    Male                                   60
# 58    Whittaker       NaN    Male                                   64
# 87     Kahaleel       NaN    Male                                    5
# 155        Bill       NaN  Female                                   74
# 202        Glyn       NaN    Male                                   47
# 326     Haleigh       NaN  Female                                   17
# 330        Alon       NaN    Male                                   17
# 357        Otis       NaN    Male                                   59
# 419     Sherill       NaN  Female                                   33
# 442   Theresina       NaN  Female                                   30
# 455     Laurena       NaN  Female                                   21
# 474      Laurie       NaN    Male                                   31
# ...

# %%
New_Customer["last_name"] = New_Customer["last_name"].fillna(value="missing")
New_Customer[New_Customer["last_name"]=="missing"]
# Out:
#      first_name last_name  gender  past_3_years_bike_related_purchases  \
# 12         Olag   missing    Male                                   60
# 58    Whittaker   missing    Male                                   64
# 87     Kahaleel   missing    Male                                    5
# 155        Bill   missing  Female                                   74
# 202        Glyn   missing    Male                                   47
# 326     Haleigh   missing  Female                                   17
# 330        Alon   missing    Male                                   17
# 357        Otis   missing    Male                                   59
# 419     Sherill   missing  Female                                   33
# 442   Theresina   missing  Female                                   30
# 455     Laurena   missing  Female                                   21
# 474      Laurie   missing    Male                                   31
# ...

# %%
New_Customer["fullname"] = New_Customer["first_name"] +" " + New_Customer["last_name"]
len(set(New_Customer["fullname"])) != len(New_Customer["fullname"])
# Out:
# False

# %%
New_Customer["fullname"][New_Customer["last_name"].isnull()]
# Out:
# Series([], Name: fullname, dtype: object)

# %% [markdown]
# ### gender

# %%
New_Customer["gender"].value_counts()
# Out:
# gender
# Female    513
# Male      470
# U          17
# Name: count, dtype: int64

# %%
sns.boxplot(y = New_Customer["past_3_years_bike_related_purchases"],data =New_Customer)
# Out:
# <Axes: ylabel='past_3_years_bike_related_purchases'>

# %%
New_Customer[New_Customer["DOB"].isnull()]
# Out:
#     first_name    last_name gender  past_3_years_bike_related_purchases  DOB  \
# 59       Normy     Goodinge      U                                    5  NaN
# 226      Hatti     Carletti      U                                   35  NaN
# 324   Rozamond       Turtle      U                                   69  NaN
# 358      Tamas      Swatman      U                                   65  NaN
# 360      Tracy   Andrejevic      U                                   71  NaN
# 374     Agneta      McAmish      U                                   66  NaN
# 434      Gregg      Aimeric      U                                   52  NaN
# 439      Johna       Bunker      U                                   93  NaN
# 574    Harlene         Nono      U                                   69  NaN
# 598   Gerianne       Kaysor      U                                   15  NaN
# 664     Chicky      Sinclar      U                                   43  NaN
# ...

# %%
indexDOB = New_Customer[New_Customer["DOB"].isnull()].index
New_Customer.drop(indexDOB , inplace=True)

# %%
New_Customer.shape
# Out:
# (983, 24)

# %%
New_Customer["DOB"] = pd.to_datetime(New_Customer["DOB"],format = '%Y-%m-%d')

# %%
sns.boxplot(x =New_Customer["DOB"].dt.month, y = New_Customer["DOB"].dt.day, data=New_Customer)
plt.show()

# %%
pd.set_option("display.max_rows", None)
New_Customer["job_title"].value_counts()
# Out:
# job_title
# Environmental Tech                      14
# Software Consultant                     14
# Associate Professor                     14
# Chief Design Engineer                   13
# Cost Accountant                         12
# Assistant Manager                       12
# Senior Sales Associate                  12
# VP Sales                                12
# Assistant Media Planner                 11
# Environmental Specialist                11
# VP Marketing                            11
# Payment Adjustment Coordinator          11
# Social Worker                           11
# Junior Executive                        11
# Nurse Practicioner                      11
# Account Executive                       11
# VP Quality Control                      11
# Librarian                               10
# Dental Hygienist                        10
# Chemical Engineer                       10
# Product Engineer                        10
# ...

# %%
New_Customer[New_Customer["job_title"].isnull()]
# Out:
#      first_name    last_name  gender  past_3_years_bike_related_purchases  \
# 15        Dukie        Swire    Male                                   88
# 25       Rourke     Gillbard    Male                                   11
# 29        Rhona    De Freyne  Female                                   45
# 30      Sharron    Claibourn  Female                                   62
# 37     Mitchell     MacCague    Male                                   58
# 38        Garik     Whitwell    Male                                   44
# 39      Antonin        Britt    Male                                   64
# 40        Vinny      Incogna  Female                                   73
# 42        Neile       Argent  Female                                   79
# 44       Brooke       Arling    Male                                   76
# 50     Heinrick    Shilstone    Male                                   60
# 53       Odessa    Mc Andrew  Female                                   97
# ...

# %%
for i in ["job_industry_category","wealth_segment","deceased_indicator","owns_car"]:
    print(New_Customer[i].value_counts())
    print("----------------------------")
# Out:
# job_industry_category
# Financial Services    202
# Manufacturing         199
# Health                152
# Retail                 78
# Property               64
# Entertainment          36
# IT                     36
# Argiculture            26
# Telecommunications     25
# Name: count, dtype: int64
# ----------------------------
# wealth_segment
# Mass Customer        499
# High Net Worth       249
# Affluent Customer    235
# Name: count, dtype: int64
# ----------------------------
# deceased_indicator
# N    983
# Name: count, dtype: int64
# ----------------------------
# owns_car
# No     497
# Yes    486
# Name: count, dtype: int64
# ----------------------------

# %%
New_Customer.drop("deceased_indicator",axis=1)
# Out:
#         first_name              last_name  gender  \
# 0          Chickie                Brister    Male
# 1            Morly                 Genery    Male
# 2          Ardelis              Forrester  Female
# 3           Lucine                  Stutt  Female
# 4          Melinda                 Hadlee  Female
# 5            Druci                Brandli  Female
# 6         Rutledge                  Hallt    Male
# 7           Nancie                   Vian  Female
# 8             Duff              Karlowicz    Male
# 9          Barthel                 Docket    Male
# 10        Rockwell                 Matson    Male
# 11         Wheeler                Winward    Male
# 12            Olag                missing    Male
# 13           Melba               Spellacy  Female
# 14          Mandie                 Feares  Female
# 15           Dukie                  Swire    Male
# 16        Marcelia              Monkleigh  Female
# 17       Winnifred           Beswetherick  Female
# ...

# %%
sns.boxplot(y = New_Customer["tenure"],data =New_Customer)
# Out:
# <Axes: ylabel='tenure'>

# %%
pd.set_option("display.max_rows", None)
New_Customer["address"].value_counts()
# Out:
# address
# 45 Shopko Center              1
# 7 Beilfuss Road               1
# 7 Elgar Hill                  1
# 36506 Bartillon Point         1
# 8 Scott Drive                 1
# 653 2nd Park                  1
# 22 Shelley Plaza              1
# 504 Stuart Pass               1
# 264 Valley Edge Pass          1
# 5 Southridge Hill             1
# 539 Graceland Pass            1
# 22435 Barnett Court           1
# 46057 Harbort Hill            1
# 2 Shasta Place                1
# 77608 Donald Center           1
# 0433 La Follette Road         1
# 8593 Prairie Rose Way         1
# 179 Carey Terrace             1
# 3 Ruskin Hill                 1
# 87 Crescent Oaks Alley        1
# 08822 Duke Road               1
# 5 Schurz Street               1
# 344 Darwin Junction           1
# 320 Acker Drive               1
# 2874 Bay Hill                 1
# 3 Sunbrook Alley              1
# 34 Jay Hill                   1
# 78 Bluestem Road              1
# 0 Express Lane                1
# ...

# %%
sns.boxplot(y = New_Customer["postcode"],data =New_Customer)
# Out:
# <Axes: ylabel='postcode'>

# %%
New_Customer["state"].value_counts()
# Out:
# state
# NSW    499
# VIC    258
# QLD    226
# Name: count, dtype: int64

# %%
New_Customer["country"].value_counts()
# Out:
# country
# Australia    983
# Name: count, dtype: int64

# %%
sns.boxplot(y = New_Customer["property_valuation"],data =New_Customer)
# Out:
# <Axes: ylabel='property_valuation'>

# %%
New_Customer["property_valuation"].sort_values().head(10)
# Out:
# 419    1.0
# 108    1.0
# 35     1.0
# 224    1.0
# 440    1.0
# 348    1.0
# 377    1.0
# 46     1.0
# 126    1.0
# 127    1.0
# Name: property_valuation, dtype: float64

# %%
col_rename = {"Unnamed: 16" : "missing_colname 16","Unnamed: 17" : "missing_colname 17","Unnamed: 18" : "missing_colname 18","Unnamed: 19" : "missing_colname 19","Unnamed: 20" : "missing_colname 20"}
New_Customer.rename(columns = col_rename, inplace = True)

# %%
New_Customer.iloc[:,16:21]
# Out:
#      missing_colname 16  missing_colname 17  missing_colname 18  \
# 0                  1.03              1.2875            1.609375
# 1                  0.44              0.4400            0.550000
# 2                  0.57              0.5700            0.570000
# 3                  0.79              0.9875            0.987500
# 4                  0.72              0.7200            0.900000
# 5                  0.91              1.1375            1.137500
# 6                  0.87              0.8700            0.870000
# 7                  0.63              0.7875            0.787500
# 8                  0.94              1.1750            1.468750
# 9                  0.48              0.6000            0.600000
# 10                 0.42              0.4200            0.525000
# 11                 0.67              0.6700            0.670000
# 12                 0.73              0.7300            0.912500
# 13                 0.81              0.8100            1.012500
# ...

# %%
sns.boxplot(x = New_Customer["Rank"],data = New_Customer)
# Out:
# <Axes: xlabel='Rank'>

# %%
sns.boxplot(x = New_Customer["Value"],data = New_Customer)
# Out:
# <Axes: xlabel='Value'>

# %%
New_Customer.isnull().sum()
# Out:
# first_name                               0
# last_name                                0
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                      0
# job_title                              105
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# missing_colname 16                       0
# missing_colname 17                       0
# missing_colname 18                       0
# missing_colname 19                       0
# missing_colname 20                       0
# Rank                                     0
# ...

# %%
New_Customer["AGE"] =  2017-New_Customer["DOB"].dt.year

# %%
sns.boxplot(y = New_Customer["AGE"],data = New_Customer)
# Out:
# <Axes: ylabel='AGE'>

# %%
New_Customer.isnull().sum()
# Out:
# first_name                               0
# last_name                                0
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                      0
# job_title                              105
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# missing_colname 16                       0
# missing_colname 17                       0
# missing_colname 18                       0
# missing_colname 19                       0
# missing_colname 20                       0
# Rank                                     0
# ...

# %%
New_Customer.to_csv("C:/Users/matages/Desktop/Customer Segmentation/Clean_data/New_Customer_Clean.csv")
